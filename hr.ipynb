# %%
print("Welcome to your Simple Quiz Chatbot!")
print("Answer the questions by typing a, b, c, or d\n")

score = 0

questions = [
    {
        "question": "1. What is the largest planet in our solar system?",
        "A": "Earth",
        "B": "Mars",
        "C": "Jupiter",
        "D": "Saturn",
        "Answer": "C"
    },
    {
        "question": "2. Who wrote Romeo and Juliet?",
        "A": "Charles Dickens",
        "B": "William Shakespeare",
        "C": "Mark Twain",
        "D": "Jane Austen",
        "Answer": "B"
    },
    {
        "question": "3. What is the chemical symbol for gold?",
        "A": "Ag",
        "B": "Au",
        "C": "Go",
        "D": "Gd",
        "Answer": "B"
    },
    {
        "question": "4. Which country currently has the largest population?",
        "A": "USA",
        "B": "India",
        "C": "China",
        "D": "Indonesia",
        "Answer": "B"
    },
    {
        "question": "5. In which year did World War II end?",
        "A": "1939",
        "B": "1942",
        "C": "1945",
        "D": "1950",
        "Answer": "C"
    },
    {
        "question": "6. Which gas do plants absorb during photosynthesis?",
        "A": "Oxygen",
        "B": "Carbon dioxide",
        "C": "Nitrogen",
        "D": "Hydrogen",
        "Answer": "B"
    },
    {
        "question": "7. Who is known as the Father of Computers?",
        "A": "Alan Turing",
        "B": "Charles Babbage",
        "C": "Isaac Newton",
        "D": "Albert Einstein",
        "Answer": "B"
    },
    {
        "question": "8. What is the hardest natural substance on Earth?",
        "A": "Diamond",
        "B": "Graphite",
        "C": "Gold",
        "D": "Quartz",
        "Answer": "A"
    },
    {
        "question": "9. Which continent is called the Dark Continent?",
        "A": "Asia",
        "B": "Australia",
        "C": "Africa",
        "D": "Europe",
        "Answer": "C"
    },
    {
        "question": "10. What is the square root of 144?",
        "A": "10",
        "B": "11",
        "C": "12",
        "D": "14",
        "Answer": "C"
    }
]
for q in questions:
    print(q["question"])
    print("A.", q["A"])
    print("B.", q["B"])
    print("C.", q["C"])
    print("D.", q["D"])
    
    user_answer = input("Your answer: ").upper()
    if user_answer == q["Answer"]:
        print("Correct!\n")
        score += 1
    else:
        print(f"Wrong! The correct answer is {q['Answer']}\n")

print(f"Quiz finished! Your score is {score}/{len(questions)}")
# Out:
# Welcome to your Simple Quiz Chatbot!
# Answer the questions by typing a, b, c, or d
#
# 1. What is the largest planet in our solar system?
# A. Earth
# B. Mars
# C. Jupiter
# D. Saturn
# Your answer:  C
# Correct!
#
# 2. Who wrote Romeo and Juliet?
# A. Charles Dickens
# B. William Shakespeare
# C. Mark Twain
# D. Jane Austen
# Your answer:  B
# Correct!
#
# 3. What is the chemical symbol for gold?
# A. Ag
# B. Au
# C. Go
# D. Gd
# Your answer:  B
# Correct!
#
# 4. Which country currently has the largest population?
# A. USA
# B. India
# C. China
# D. Indonesia
# Your answer:  B
# Correct!
#
# 5. In which year did World War II end?
# A. 1939
# B. 1942
# C. 1945
# D. 1950
# Your answer:  C
# Correct!
#
# 6. Which gas do plants absorb during photosynthesis?
# A. Oxygen
# B. Carbon dioxide
# C. Nitrogen
# D. Hydrogen
# Your answer:  B
# Correct!
#
# 7. Who is known as the Father of Computers?
# A. Alan Turing
# B. Charles Babbage
# C. Isaac Newton
# D. Albert Einstein
# Your answer:  B
# ...
